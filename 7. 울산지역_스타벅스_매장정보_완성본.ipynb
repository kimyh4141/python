# %% [markdown]
# # 스타벅스 매장 정보 스크래핑(울산)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import bs4
import time
import pandas as pd

# 크롬 브라우저 실행
driver = webdriver.Chrome("C:/Users/admin/chromedriver_win32/chromedriver.exe")

#크롬 브라우저에서 스타벅스 매장 정보 싸이트에 접속하고 코드를 작성!
driver.get('https://www.starbucks.co.kr/store/store_map.do')

#싸이트 접속 후 3초간 대기하는 코드를 작성!
time.sleep(3)

# 지역 검색 버튼을 찾는 코드를 작성
loca = driver.find_element(By.CLASS_NAME, "loca_search")

# 찾은 버튼을 클릭하는 코드를 작성
loca.click()

#3초가 대기한다.
time.sleep(3)

# 시/도 정보가 위치한 태그를 찾는 코드 작성
sido = driver.find_element(By.CLASS_NAME, 'sido_arae_box')

# 시/도 정보가 위치한 태그 안의 모든 li 태그를 찾는 코드 작성
li = sido.find_elements(By.TAG_NAME, 'li')

# 울산 지역의 <li>태그를 클릭한다. 
# python은 숫자를 샐 때 0부터 시작한다.!
li[6].click()

# 3초간 대기
time.sleep(3)

# 구/군 정보가 위치한 태그를 찾는 코드 작성
gugun = driver.find_element(By.CLASS_NAME,'gugun_arae_box')

# 구/군 정보가 위치한 태그 안에서 전체 구군에 대한 
# li 태그를 찾는 코드 작성
total_gugun = gugun.find_element(By.TAG_NAME, "li") 

# 찾은 태그 클릭
total_gugun.click()

#3초간 대기
time.sleep(3)

# 현재 열려 있는 페이지의 모든 정보를 BeautifulSoup 형태로 변환(BeautifulSoup으로 변환하면 데이터를 가져 오지 편하다.)
bs = bs4.BeautifulSoup(driver.page_source, 'lxml')

#매장 이름이 있는 태그를 선택한다.(class가 loca_step3인 div태그를 선택)
entire=bs.find('div', class_='loca_step3')

#찾은 태그 안에서 li태그를 모두 선택한다.
li_list = entire.findAll('li')

# 스크래핑한 데이터를 엑셀로 추출하기 위한 작업 시작!

nameList = [] #매장명을 저장할 변수
arrList = [] #매장의 주소를 저장할 변수
tellList = [] #매장의 연락처를 저장할 변수

#li_list의 개수만큼 반복을 시작한다.
#li_list의 데이터를 하나씩 빼서 infor라는 이름을 부여한다.
for infor in li_list:
    #매장 이름을 추출
    name = infor.find('strong').get_text()
    
    #추출한 매장 이름을 nameList에 추가
    nameList.append(name)
    
    #매장 주소와 연락처 정보를 추출
    arrAndTell = infor.find('p').get_text()
   
    #주소 정보만 추출
    arr = arrAndTell[:-9]
    
    #추출한 주소 정보를 arrList에 추가
    arrList.append(arr)
    
    #연락처 정보만 추출
    tell = arrAndTell[-9:]
    
    #추출한 연락처 정보를 tellList 추가
    tellList.append(tell)
    # -- for문 종료!
    
#스크래핑한 모든 정보를 하나의데이터의 저장
data = {
    '상호명':nameList
    , '주소':arrList
    , '연락처':tellList
}   

df = pd.DataFrame(data)

#엑셀 파일로 저장
df.to_excel('스타벅스_매장정보.xlsx')

#완성된 출력
df
# Out:
# C:\Users\KH302\AppData\Local\Temp\ipykernel_10276\486386572.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/Users/admin/chromedriver_win32/chromedriver.exe")
#             상호명                                   주소        연락처
# 0       울산번영로                  울산광역시 남구 삼산로 182 (달동)  1522-3232
# 1       울산대공원                 울산광역시 남구 대공원입구로 4 (옥동)  1522-3232
# 2   울산도산사거리DT            울산광역시 남구 대암로129번길 9-6 (야음동)  1522-3232
# 3   울산시청사거리DT                  울산광역시 남구 중앙로 180 (달동)  1522-3232
# 4     울산남구청DT                 울산광역시 남구 번영로 215 (신정동)  1522-3232
# 5   울산중리사거리DT                 울산광역시 남구 돋질로 310 (삼산동)  1522-3232
# 6       울산센트럴                  울산광역시 남구 삼산로 231 (달동)  1522-3232
# 7       울산삼산로            울산광역시 남구 삼산로 278 번길 8 (삼산동)  1522-3232
# 8         울산대             울산광역시 남구 대학로84번길 5-3 (무거동)  1522-3232
# 9     울산디자인거리     울산광역시 남구 삼산중로74번길 30-1, 1~2층 (삼산동)  1522-3232
# 10       울산신복                 울산광역시 남구 대학로 152 (무거동)  1522-3232
# 11     울산삼산대로              울산광역시 남구 삼산로 257, 1층 (달동)  1522-3232
# 12    울산번영로DT                    울산광역시 남구 달삼로 3 (달동)  1522-3232
# 13    울산삼성프라자                   울산광역시 남구 삼산로 86 (달동)  1522-3232
# 14     울산신정DT                 울산광역시 남구 문수로 435 (신정동)  1522-3232
# 15     울산호계DT                울산광역시 북구 산업로 1464 (신천동)  1522-3232
# 16    울산북구청DT                울산광역시 북구 산업로 1011 (연암동)  1522-3232
# 17       울산진장                울산광역시 북구 진장17길 10 (진장동)  1522-3232
# 18   울산정자비치DT               울산광역시 북구 동해안로 1601 (산하동)  1522-3232
# 19       울산화봉                  울산광역시 북구 화봉로 75 (화봉동)  1522-3232
# 20   북울산삼성프라자                울산광역시 북구 진장유통로 65 (진장동)  1522-3232
# 21      울산간절곶                울산광역시 울주군 서생면 대송리 25-18  1522-3232
# 22     울산 KTX                 울산광역시 울주군 삼남읍 도호1길 16   1522-3232
# 23   울산MBC DT                 울산광역시 중구 번영로 434 (복산동)  1522-3232
# 24       울산성안                울산광역시 중구 성안12길 45 (성안동)  1522-3232
# 25    울산성남삼거리               울산광역시 중구 젊음의2거리 33 (성남동)  1522-3232
# 26     울산약사DT              울산광역시 중구 북부순환도로 754 (약사동)  1522-3232
# 27     울산국가정원            울산광역시 중구 태화강국가정원길 205 (태화동)  1522-3232
# 28       현대동구    울산광역시 동구 방어진순환도로 899 (서부동) 현대백화점주차장  1522-3232
# 29    울산테라스파크             울산광역시 동구 방어진순환도로 652 (일산동)  1522-3232
# 30   울산일산비치DT               울산광역시 동구 일산진11길 95 (일산동)  1522-3232
# 31    울산대학교병원             울산광역시 동구 방어진순환도로 879 (서부동)  1522-3232
# 32     현대동구5F             울산광역시 동구 방어진순환도로 899 (서부동)  1522-3232
# 33     울산주전비치                울산광역시 동구 동해안로 667 (주전동)  1522-3232
